# %%
import pandas as pd

# %% [markdown]
# Import datasets - literature data & journal impact factors 2020

# %%
# load given dataset
lit_df = pd.read_csv('Literature-data_TU-Darmstadt.txt', sep = '\t', header = 1, skiprows = [3])
lit_df
# Out:
#      Quelle                                              Autor  \
# 0       WOS  Chaudhary, Ayesha Hoor; Bukhari, Faisal; Iqbal...
# 1       WOS  Kim, Soo-Kyun; Lee, Chang-Hee; Kim, Sun-Jeong;...
# 2       WOS                     Lee, Byong Kwon; Lee, Yang Sun
# 3       WOS  Frederiksen, Joakim Grant; Sorensen, Stine May...
# 4       WOS      Rafique, Muhammad Usman; Cheung, Sen-ching S.
# ...     ...                                                ...
# 1064     SB  Grechkin, TY; Nguyen, TD; Plumert, JM; Cremer,...
# 1065     SB  Hu, B; Ma, L; Zhang, W; Salvendy, G; Chablat, ...
# 1066     SB  Taylor W. Cleworth, Brian C. Horslen, Mark G. ...
# 1067     SB  Ouellet,É; Boller, B; Corriveau-Lecavalier, N;...
# 1068     SB                     Li, Z; Phillips, J; Durgin, FH
#
#                                                   Titel  Jahr  \
# 0        Laparoscopic Training Exercises Using HTC VIVE  2020
# 1     Implementation of Local Area VR Environment us...  2020
# ...

# %% [markdown]
# Quelle: WOS, BSP, SB
# Jahr: 1993-2020

# %%
# load dataset of journal impact factors
# from https://www.kaggle.com/datasets/mostafafaramin/scientific-journals-ranking-sjr
journal_df = pd.read_csv('journal_impact_factors_2020.csv')
journal_df
# Out:
#         Rank                                 Full Journal Title  \
# 0          1                 CA-A CANCER JOURNAL FOR CLINICIANS
# 1          2                    NEW ENGLAND JOURNAL OF MEDICINE
# 2          3                           Nature Reviews Materials
# 3          4                      NATURE REVIEWS DRUG DISCOVERY
# 4          5                                             LANCET
# ...      ...                                                ...
# 12850  12838  Photobiomodulation Photomedicine and Laser Sur...
# 12851  12838          Polymer-Plastics Technology and Materials
# 12852  12838             Sexual and Reproductive Health Matters
# 12853  12838                      Wound Management & Prevention
# 12854  12838                      Wound Management & Prevention
#
#       Journal Impact Factor  Impact Factor without Journal Self Cites  \
# 0                   292.278                                   291.481
# ...

# %% [markdown]
# which rows to keep (only take rows that have journal titles in both datasets?)

# %% [markdown]
# preprocess/clean data - make into csv with strings?
# - 1069 rows total
# - DOI NaN: 31
# - DOI 0: 29
# - DOI duplicates: 75
#
# - Titel duplicates: 3
# - 'Dopplung': 77
#
# remove rows: ausschlusspunkt = dopplung (see if one has DOI and one doesn't/edit Ausschlusspunkt if necessary), duplicate DOI, duplicate title
# journal/paper titles: make all lowercase?

# %% [markdown]
# rows with Ausschlusspunkt = Dopplung

# %%
lit_df[lit_df['Ausschlusspunkt'] == 'Dopplung']
# Out:
#      Quelle                                              Autor  \
# 666     BSP  Peukert, Christian; Pfeiffer, Jella; Meißner, ...
# 667     BSP  Liang, Hai-Ning; Lu, Feiyu; Shi, Yuwei; Nanjap...
# 668     BSP  Somrak, Andrej; Humar, Iztok; Hossain, M. Sham...
# 669     BSP        Newbutt, Nigel; Bradley, Ryan; Conley, Iian
# 670     BSP              Aldaba, Cassandra N.; Moussavi, Zahra
# ...     ...                                                ...
# 1052    BSP            Jankowski, Jaros?aw; Grabowski, Andrzej
# 1053    BSP  Nyberg, Lars; Lundin-Olsson, Lillemor; Sondell...
# 1056    BSP  Crosbie, J. H.; Lennon, S.; McNeill, M. D. J.;...
# 1057    BSP  Schneider, Susan M.; Ellis, Mathew; Coombs, Wi...
# 1059    BSP  Dahlquist, Lynnda M.; Herbert, Linda J.; Weiss...
#
#                                                   Titel  Jahr  \
# 666   Shopping in Virtual Reality Stores: The Influe...  2019
# 667   Evaluating the effects of collaboration and co...  2019
# ...

# %% [markdown]
# rows with duplicate DOIs (not NaN or 0)

# %%
x = lit_df[lit_df['DOI'].duplicated()]
x[(x['DOI'] != '0') & (x['DOI'].notnull())]
# Out:
#      Quelle                                              Autor  \
# 667     BSP  Liang, Hai-Ning; Lu, Feiyu; Shi, Yuwei; Nanjap...
# 668     BSP  Somrak, Andrej; Humar, Iztok; Hossain, M. Sham...
# 669     BSP        Newbutt, Nigel; Bradley, Ryan; Conley, Iian
# 670     BSP              Aldaba, Cassandra N.; Moussavi, Zahra
# 671     BSP               Feldstein, Ilja T.; Dyszak, Georg N.
# ...     ...                                                ...
# 1052    BSP            Jankowski, Jaros?aw; Grabowski, Andrzej
# 1053    BSP  Nyberg, Lars; Lundin-Olsson, Lillemor; Sondell...
# 1056    BSP  Crosbie, J. H.; Lennon, S.; McNeill, M. D. J.;...
# 1057    BSP  Schneider, Susan M.; Ellis, Mathew; Coombs, Wi...
# 1059    BSP  Dahlquist, Lynnda M.; Herbert, Linda J.; Weiss...
#
#                                                   Titel  Jahr  \
# 667   Evaluating the effects of collaboration and co...  2019
# 668   Estimating VR Sickness and user experience usi...  2019
# ...

# %% [markdown]
# example of two rows with duplicate DOIs

# %%
lit_df[lit_df['DOI'] == lit_df.iloc[667]['DOI']]
# Out:
#     Quelle                                              Autor  \
# 92     WOS  Liang, Hai-Ning; Lu, Feiyu; Shi, Yuwei; Nanjap...
# 667    BSP  Liang, Hai-Ning; Lu, Feiyu; Shi, Yuwei; Nanjap...
#
#                                                  Titel  Jahr  \
# 92   Evaluating the effects of collaboration and co...  2019
# 667  Evaluating the effects of collaboration and co...  2019
#
#                                                Journal  Typ  \
# 92   FUTURE GENERATION COMPUTER SYSTEMS-THE INTERNA...  NaN
# 667                 Future Generation Computer Systems  NaN
#
#                               DOI Gelesen? Empirisch? Ausschlusspunkt  ...  \
# 92   10.1016/j.future.2018.02.029    Görge         Ja        Volltext  ...
# 667  10.1016/j.future.2018.02.029    Görge        NaN        Dopplung  ...
#
#     Cognitive / Memory tasks Spatial Perception Quantitative Qualitative  \
# 92                       NaN                NaN          NaN         NaN
# ...

# %% [markdown]
# rows with duplicate titles

# %%
lit_df[lit_df['Titel'].duplicated()]
# Out:
#      Quelle                                              Autor  \
# 800     WOS                            Riva, G; Wiederhold, BK
# 1012    BSP  Simpson, Gordon; Johnston, Lucy; Richardson, M...
# 1059    BSP  Dahlquist, Lynnda M.; Herbert, Linda J.; Weiss...
#
#                                                   Titel  Jahr  \
# 800   The New Dawn of Virtual Reality in Health Care...  2015
# 1012  An investigation of road crossing in a virtual...  2003
# 1059  Virtual-Reality Distraction and Cold-Pressor P...  2010
#
#                                                 Journal  \
# 800   ANNUAL REVIEW OF CYBERTHERAPY AND TELEMEDICINE...
# 1012                     Accident Analysis & Prevention
# 1059      CyberPsychology, Behavior & Social Networking
#
#                         Typ                            DOI Gelesen?  \
# 800   Article; Book Chapter    10.3233/978-1-61499-595-1-3      NaN
# 1012                Article  10.1016/S0001-4575(02)00081-7      NaN
# ...

# %% [markdown]
# example of duplicate titles

# %%
lit_df[lit_df['Titel'] == lit_df.iloc[800]['Titel']]
# Out:
#     Quelle                    Autor  \
# 782    WOS  Riva, G; Wiederhold, BK
# 800    WOS  Riva, G; Wiederhold, BK
#
#                                                  Titel  Jahr  \
# 782  The New Dawn of Virtual Reality in Health Care...  2015
# 800  The New Dawn of Virtual Reality in Health Care...  2015
#
#                                                Journal                    Typ  \
# 782     ANNUAL REVIEW OF CYBERTHERAPY AND TELEMEDICINE                Article
# 800  ANNUAL REVIEW OF CYBERTHERAPY AND TELEMEDICINE...  Article; Book Chapter
#
#                              DOI Gelesen? Empirisch? Ausschlusspunkt  ...  \
# 782                          NaN      NaN       Nein        Abstract  ...
# 800  10.3233/978-1-61499-595-1-3      NaN       nein        Dopplung  ...
#
#     Cognitive / Memory tasks Spatial Perception Quantitative Qualitative  \
# 782                      NaN                NaN          NaN         NaN
# ...
