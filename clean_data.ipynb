# %%
import pandas as pd

# %% [markdown]
# Import datasets - literature data & journal impact factors 2020

# %%
# load given dataset
lit_df = pd.read_csv('Literature-data_TU-Darmstadt.txt', sep = '\t', header = 1, skiprows = [3])
lit_df
# Out:
#      Quelle                                              Autor  \
# 0       WOS  Chaudhary, Ayesha Hoor; Bukhari, Faisal; Iqbal...
# 1       WOS  Kim, Soo-Kyun; Lee, Chang-Hee; Kim, Sun-Jeong;...
# 2       WOS                     Lee, Byong Kwon; Lee, Yang Sun
# 3       WOS  Frederiksen, Joakim Grant; Sorensen, Stine May...
# 4       WOS      Rafique, Muhammad Usman; Cheung, Sen-ching S.
# 5       WOS                     Checa, David; Bustillo, Andres
# 6       WOS  Ammann, Jeanine; Hartmann, Christina; Peterhan...
# 7       WOS  Curry, Christopher; Li, Ruixuan; Peterson, Nic...
# 8       WOS  Lee, Sang Hyeok; Kim, Martha; Kim, Hyosun; Par...
# 9       WOS  Ping, Jiamin; Weng, Dongdong; Liu, Yue; Wang, ...
# 10      WOS  Fransson, Goran; Holmberg, Jorgen; Westelius, ...
# 11      WOS  Appel, Lora; Appel, Eva; Bogler, Orly; Wiseman...
# 12      WOS                      Griffin, Tom; Muldoon, Meghan
# 13      WOS  Na, Woongsoo; Dao, Nhu-Ngoc; Kim, Joongheon; R...
# ...

# %% [markdown]
# Quelle: WOS, BSP, SB
# Jahr: 1993-2020

# %%
# load dataset of journal impact factors
# https://www.kaggle.com/datasets/mostafafaramin/scientific-journals-ranking-sjr
journal_df = pd.read_csv('journal_impact_factors_2020.csv')
journal_df
# Out:
#         Rank                                 Full Journal Title  \
# 0          1                 CA-A CANCER JOURNAL FOR CLINICIANS
# 1          2                    NEW ENGLAND JOURNAL OF MEDICINE
# 2          3                           Nature Reviews Materials
# 3          4                      NATURE REVIEWS DRUG DISCOVERY
# 4          5                                             LANCET
# 5          6                        WHO Technical Report Series
# 6          7              NATURE REVIEWS MOLECULAR CELL BIOLOGY
# 7          8                   Nature Reviews Clinical Oncology
# 8          9                              NATURE REVIEWS CANCER
# 9         10                                   CHEMICAL REVIEWS
# 10        11                                      Nature Energy
# 11        12   JAMA-JOURNAL OF THE AMERICAN MEDICAL ASSOCIATION
# 12        13                          REVIEWS OF MODERN PHYSICS
# 13        14                           CHEMICAL SOCIETY REVIEWS
# ...

# %% [markdown]
# project idea: ??

# %% [markdown]
# create schema: which columns to keep, which rows to keep

# %% [markdown]
# (draw ER model, make postgresql database)

# %% [markdown]
# preprocess/clean data - make into csv with strings?

# %% [markdown]
# use itables? https://marc-wouts.medium.com/pandas-dataframes-as-interactive-html-datatables-9737c7266abf
